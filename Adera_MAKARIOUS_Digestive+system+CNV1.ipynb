# %% [markdown]
# <a href="https://colab.research.google.com/github/michel-phylo/CNV_ADERA/blob/main/Adera_MAKARIOUS_Digestive%2Bsystem%2BCNV1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# !ls
# Out:
# Mounted at /content/gdrive/
# gdrive	sample_data

# %%
# %cd gdrive/MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
# !ls

# %%
# !pip3 install tensorflow

from absl import logging

import tensorflow as tf

import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import seaborn as sns
import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import time
from IPython import display
from tensorflow.keras.constraints import max_norm

import pandas as pd
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.56.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.13)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)

# %%
import pandas as pd

#first_data_adera=pd.read_table('updated_ADERA_GENES_6500_gene8g.txt',delimiter='\t',engine='python')
#first_data_adera=pd.read_table('updated_ADERA_GENES_6500_gene8g_onely_main.txt',delimiter='\t',engine='python')
first_data_adera=pd.read_table('updated_ADERA_GENES_6500_gene8g.txt',delimiter='\t',engine='python')
#first_data_adera=pd.read_table('updated_ADERA_GENES_6500_genec_only_main_14.txt',delimiter='\t',engine='python')
#first_data_adera=pd.read_table('Adera_Complete_data_base_10_july_v1_2_38pm.txt',delimiter=',',engine='python')

first_data_adera
# Out:
#          Gene     CNA  Freq  chromosome        start          end  strand  \
# 0       A2ML1     AMP   6.0          12    8822621.0    8887001.0      77
# 1       A4GNT     AMP   6.8           3  138123713.0  138132390.0       3
# 2       A4GNT     AMP   6.0           3  138123713.0  138132390.0       3
# 3      AACSP1     AMP   7.3           5  178764861.0  178818435.0       3
# 4       AADAC     AMP   8.2           3  151814073.0  151828488.0      77
# ...       ...     ...   ...         ...          ...          ...     ...
# 12979    ZUP1  HOMDEL   8.3           6  116635618.0  116668794.0       3
# 12980    ZUP1  HOMDEL   6.5           6  116635618.0  116668794.0       3
# 12981    ZUP1  HOMDEL   6.3           6  116635618.0  116668794.0       3
# 12982    ZXDC     AMP   6.1           3  126437601.0  126475891.0       3
# 12983     ZYX     AMP   8.0           7  143381295.0  143391111.0      77
#
#                             Cancer_type
# 0           Testicular_Germ_Cell_Tumors
# 1      Cervical_Squamous_Cell_Carcinoma
# 2             Esophageal_Adenocarcinoma
# 3            Renal_Clear_Cell_Carcinoma
# 4      Cervical_Squamous_Cell_Carcinoma
# ...                                 ...
# 12979     Diffuse_Large B-Cell_Lymphoma
# 12980           Prostate_Adenocarcinoma
# 12981                    Uveal Melanoma
# 12982  Cervical_Squamous_Cell_Carcinoma
# 12983             Serous_Ovarian_Cancer
#
# [12984 rows x 8 columns]

# %%
first_data_adera1= first_data_adera.dropna(axis = 0, how ='any')
first_data_adera1
#first_data_adera2 = first_data_adera1.sort_values(by=['Freq'], ascending=[ False])
first_data_adera3 = first_data_adera1.sort_values(by=['Gene', 'Cancer_type', 'Freq'], ascending=[True, True, False])
first_data_adera3
first_data_adera4 = first_data_adera3.drop_duplicates(subset=['Gene'], keep='first')
first_data_adera4
# Out:
#           Gene     CNA  Freq  chromosome        start          end  strand  \
# 0        A2ML1     AMP   6.0          12    8822621.0    8887001.0      77
# 1        A4GNT     AMP   6.8           3  138123713.0  138132390.0       3
# 3       AACSP1     AMP   7.3           5  178764861.0  178818435.0       3
# 4        AADAC     AMP   8.2           3  151814073.0  151828488.0      77
# 7      AADACL2     AMP   8.2           3  151733916.0  151761339.0      77
# ...        ...     ...   ...         ...          ...          ...     ...
# 12977   ZSWIM4     AMP  12.1          19   13795443.0   13832254.0      77
# 12978   ZSWIM7     AMP   9.1          17   15976560.0   15999717.0       3
# 12979     ZUP1  HOMDEL   8.3           6  116635618.0  116668794.0       3
# 12982     ZXDC     AMP   6.1           3  126437601.0  126475891.0       3
# 12983      ZYX     AMP   8.0           7  143381295.0  143391111.0      77
#
#                             Cancer_type
# 0           Testicular_Germ_Cell_Tumors
# 1      Cervical_Squamous_Cell_Carcinoma
# 3            Renal_Clear_Cell_Carcinoma
# 4      Cervical_Squamous_Cell_Carcinoma
# 7      Cervical_Squamous_Cell_Carcinoma
# ...                                 ...
# 12977             Serous_Ovarian_Cancer
# 12978                           Sarcoma
# 12979     Diffuse_Large B-Cell_Lymphoma
# 12982  Cervical_Squamous_Cell_Carcinoma
# 12983             Serous_Ovarian_Cancer
#
# [7058 rows x 8 columns]

# %%
first_data_adera["Cancer_type"].unique()
# Out:
# array(['Testicular_Germ_Cell_Tumors', 'Cervical_Squamous_Cell_Carcinoma',
#        'Esophageal_Adenocarcinoma', 'Renal_Clear_Cell_Carcinoma',
#        'Head_and_Neck_Squamous', 'Serous_Ovarian_Cancer',
#        'Colorectal_Adenocarcinoma', 'Liver_Hepatocellular_Carcinoma',
#        'Breast_Invasive_Ductal_Carcinoma', 'Stomach_Adenocarcinoma',
#        'Uterine_Corpus_Endometrial_Carcinoma',
#        'Diffuse_Large B-Cell_Lymphoma', 'Cholangiocarcinoma',
#        'Uveal Melanoma', 'Bladder_Urothelial_Carcinoma', 'Sarcoma',
#        'Prostate_Adenocarcinoma', 'Lung', 'Adrenocortical_Carcinoma',
#        'Glioblastoma_Multiforme', 'Skin_Cutaneous_Melanoma',
#        'Brain_Lower_Grade_Glioma'], dtype=object)

# %%
#First_data_adera3a= first_data_adera3[first_data_adera3['Cancer_type'] == 'Esophageal_Adenocarcinoma']
First_data_adera3b1= first_data_adera3[first_data_adera3['Cancer_type'] == 'Colorectal_Adenocarcinoma']
First_data_adera3b2= first_data_adera3[first_data_adera3['Cancer_type'] == 'Cholangiocarcinoma']
#First_data_adera3b3= first_data_adera3[first_data_adera3['Cancer_type'] == 'Stomach_Adenocarcinoma']

#First_data_adera3c = pd.concat([First_data_adera3a, First_data_adera3b1,First_data_adera3b2,First_data_adera3b3])
#First_data_adera3c = pd.concat([First_data_adera3b1, First_data_adera3b2,First_data_adera3b3])
First_data_adera3c = pd.concat([First_data_adera3b1,First_data_adera3b2])

# %%
First_data_adera3c
import pandas as pd


# Get unique cancer types in the dataset
unique_cancer_types = First_data_adera3c['Cancer_type'].unique()

# Count the rows for each cancer type
for cancer_type in unique_cancer_types:
    cancer_type_data = First_data_adera3c[First_data_adera3c['Cancer_type'] == cancer_type]
    num_rows = len(cancer_type_data)
    print("Number of rows in", cancer_type, ":", num_rows)
# Out:
# Number of rows in Colorectal_Adenocarcinoma : 442
# Number of rows in Cholangiocarcinoma : 675

# %%
#first_data_adera3[first_data_adera3['Cancer_type'] == 'Esophageal_Adenocarcinoma']
#first_data_adera3[first_data_adera3['Cancer_type'] == 'Colorectal_Adenocarcinoma']
#first_data_adera3[first_data_adera3['Cancer_type'] == 'Cholangiocarcinoma']
#first_data_adera3[first_data_adera3['Cancer_type'] == 'Stomach_Adenocarcinoma']

# %%
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(First_data_adera3c["CNA"])
Adera_CNA= encoder.transform(First_data_adera3c["CNA"])

Adera_CNA1= np_utils.to_categorical(Adera_CNA,num_classes=4)
#type(first_data_adera["Freq"])
#Adera_CNA1=first_data_adera['CNA']
Adera_CNA1.shape #rember to update because there are genes written in one or more diseases.
Adera_CNA1
type(First_data_adera3c ['CNA'])

#Input_net_Adera = np.concatenate((Adera_freq.T,Adera_CNA1), axis=None)
#Input_net_Adera1=Input_net_Adera.reshape(5,6918).T

Input_net_Adera1=Adera_CNA1
Input_net_Adera1.shape # number of samples,number of 4 states
Adera_chromosome=First_data_adera3c['chromosome']
Adera_chromosome1=np.array(Adera_chromosome)
Adera_chromosome2=Adera_chromosome1.reshape(Input_net_Adera1.shape[0],1)

Adera_start=First_data_adera3c['start']
Adera_start1=np.array(Adera_start)
Adera_start2=Adera_start1.reshape(Input_net_Adera1.shape[0],1)

Adera_end=First_data_adera3c['end']
Adera_end1=np.array(Adera_end)
Adera_end2=Adera_end1.reshape(Input_net_Adera1.shape[0],1)

Adera_strand=First_data_adera3c['strand']
Adera_strand1=np.array(Adera_strand)
Adera_strand2=Adera_strand1.reshape(Input_net_Adera1.shape[0],1)

Adera_freq=First_data_adera3c['Freq']
Adera_freq1=np.array(Adera_freq)
Adera_freq2=Adera_freq1.reshape(Input_net_Adera1.shape[0],1)
#normalise chromsoem numbers
from sklearn.preprocessing import MinMaxScaler
import numpy as np
Adera_chromosome3 = Adera_chromosome2.reshape(-1, 1)
scaler = MinMaxScaler()
Adera_chromosome4= scaler.fit_transform(Adera_chromosome3)



#####normalise start values
from sklearn.preprocessing import MinMaxScaler
import numpy as np
Adera_start3 = Adera_start2.reshape(-1, 1)
scaler = MinMaxScaler()
Adera_start4= scaler.fit_transform(Adera_start3)

####normalise end values
from sklearn.preprocessing import MinMaxScaler
import numpy as np
Adera_end3 = Adera_end2.reshape(-1, 1)
scaler = MinMaxScaler()
Adera_end4= scaler.fit_transform(Adera_end3)

######normalise stand
from sklearn.preprocessing import MinMaxScaler
import numpy as np
Adera_strand3 = Adera_strand2.reshape(-1, 1)
scaler = MinMaxScaler()
Adera_strand4= scaler.fit_transform(Adera_strand3)
Adera_chromosome4.shape
k1=First_data_adera3c["Cancer_type"].unique()
k1.shape[0]
#Input_net_Adera2 = np.concatenate((Input_net_Adera1,adera_matrix), axis=1)
Adera_CNA1
#Input_net_Adera2 = np.concatenate((Input_net_Adera1,Adera_chromosome2,Adera_start2,Adera_end2,Adera_strand2,Adera_freq2), axis=1)
Input_net_Adera2 = np.concatenate((Input_net_Adera1,Adera_chromosome4,Adera_start4,Adera_end4,Adera_strand4), axis=1)
#Input_net_Adera2 = np.concatenate((Input_net_Adera1,Adera_start2,Adera_end2), axis=1)
#Input_net_Adera2=adera_matrix
Input_net_Adera2.shape
Output_net_Adera=First_data_adera3c[["Cancer_type"]]
Output_net_Adera
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelEncoder
#encoder = LabelEncoder()
#encoder.fit(Output_net_Adera)
#Output_net_Adera1 = encoder.transform(Output_net_Adera)

#Output_net_Adera1 = np_utils.to_categorical(Output_net_Adera1,num_classes=3)
#Output_net_Adera1



encoder = LabelEncoder()
encoder.fit(First_data_adera3c[["Cancer_type"]])
Output_net_Adera1 = encoder.transform(First_data_adera3c[["Cancer_type"]])

Output_net_Adera2= np_utils.to_categorical(Output_net_Adera1 ,num_classes=k1.shape[0])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %%
Output_net_Adera2= np_utils.to_categorical(Output_net_Adera1 ,num_classes=k1.shape[0])
Output_net_Adera2.shape
Output_net_Adera2
Input_Adera_numpy2=Input_net_Adera2.reshape(Input_net_Adera1.shape[0],1,1,8) #7 input values

Output_net_Adera3=Output_net_Adera2.reshape(Input_net_Adera1.shape[0],1,1,k1.shape[0]) #7 cancer types
Output_net_Adera3
# Out:
# array([[[[0., 1.]]],
#
#
#        [[[0., 1.]]],
#
#
#        [[[0., 1.]]],
#
#
#        ...,
#
#
#        [[[1., 0.]]],
#
#
#        [[[1., 0.]]],
#
#
#        [[[1., 0.]]]], dtype=float32)

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
#from tensorflow.keras import regularizers
import numpy as np
#result_file = open("results_adera1.txt", "w")
#result_file.write(" test_adera")
#result_file.close()

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
#from tensorflow.keras import regularizers
es_ADERA = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=300)

from random import sample

class_0_indices = np.where(Output_net_Adera3 == 0)[0]
class_1_indices = np.where(Output_net_Adera3 == 1)[0]

num_samples_class_0 = len(class_0_indices)
num_samples_class_1 = len(class_1_indices)

target_size = min(num_samples_class_0, num_samples_class_1)

undersampled_indices = np.concatenate([
    sample(class_0_indices.tolist(), target_size),
    class_1_indices
])

Input_Adera_undersampled = Input_Adera_numpy2[undersampled_indices]
Output_net_Adera_undersampled = Output_net_Adera3[undersampled_indices]




grace_model = tf.keras.Sequential([

 #tf.keras.layers.Dense(2, activation='sigmoid'),
 tf.keras.layers.Dense(128, activation='relu'),
 tf.keras.layers.Dense(2, activation='sigmoid')


      ])





optimizer_Adera=tf.keras.optimizers.Adamax(learning_rate=2*1e-3, clipnorm = .08)

grace_model.compile(optimizer=optimizer_Adera, loss='binary_crossentropy', metrics=['accuracy'])
k_adera = grace_model.fit(Input_Adera_undersampled, Output_net_Adera_undersampled, verbose=1, validation_split=0.49, epochs=50, batch_size=20, callbacks=[es_ADERA])
#k_adera=grace_model.fit(Input_Adera_numpy2,Output_net_Adera3,verbose=1,validation_split=0.49,epochs=200,batch_size=10, callbacks=[es_ADERA]) # TEST1_TRAIN_0.8_adera=grace_model.fit(Input_Adera_numpy2,Output_net_Adera3,verbose=1,validation_split=0.49,epochs=350,batch_size=250, callbacks=[es_ADERA]) # TEST1_TRAIN_0.8
# Out:
# Epoch 1/50
# 57/57 [==============================] - 1s 8ms/step - loss: 0.4505 - accuracy: 0.8437 - val_loss: 0.2757 - val_accuracy: 0.9900
# Epoch 2/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.1727 - accuracy: 0.9754 - val_loss: 0.0921 - val_accuracy: 0.9744
# Epoch 3/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0700 - accuracy: 0.9737 - val_loss: 0.0546 - val_accuracy: 0.9744
# Epoch 4/50
# 57/57 [==============================] - 1s 9ms/step - loss: 0.0525 - accuracy: 0.9737 - val_loss: 0.0473 - val_accuracy: 0.9744
# Epoch 5/50
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0476 - accuracy: 0.9737 - val_loss: 0.0444 - val_accuracy: 0.9744
# Epoch 6/50
# 57/57 [==============================] - 0s 7ms/step - loss: 0.0453 - accuracy: 0.9745 - val_loss: 0.0423 - val_accuracy: 0.9753
# Epoch 7/50
# 57/57 [==============================] - 0s 6ms/step - loss: 0.0436 - accuracy: 0.9807 - val_loss: 0.0407 - val_accuracy: 0.9845
# Epoch 8/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0424 - accuracy: 0.9789 - val_loss: 0.0392 - val_accuracy: 0.9845
# Epoch 9/50
# 57/57 [==============================] - 0s 6ms/step - loss: 0.0411 - accuracy: 0.9851 - val_loss: 0.0381 - val_accuracy: 0.9845
# Epoch 10/50
# 57/57 [==============================] - 0s 6ms/step - loss: 0.0396 - accuracy: 0.9842 - val_loss: 0.0366 - val_accuracy: 0.9900
# Epoch 11/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0390 - accuracy: 0.9868 - val_loss: 0.0355 - val_accuracy: 0.9900
# Epoch 12/50
# 57/57 [==============================] - 0s 6ms/step - loss: 0.0377 - accuracy: 0.9886 - val_loss: 0.0346 - val_accuracy: 0.9900
# Epoch 13/50
# 57/57 [==============================] - 0s 6ms/step - loss: 0.0371 - accuracy: 0.9886 - val_loss: 0.0337 - val_accuracy: 0.9900
# Epoch 14/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0364 - accuracy: 0.9886 - val_loss: 0.0331 - val_accuracy: 0.9900
# Epoch 15/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0352 - accuracy: 0.9886 - val_loss: 0.0326 - val_accuracy: 0.9900
# Epoch 16/50
# 57/57 [==============================] - 0s 6ms/step - loss: 0.0348 - accuracy: 0.9886 - val_loss: 0.0318 - val_accuracy: 0.9900
# Epoch 17/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0341 - accuracy: 0.9886 - val_loss: 0.0317 - val_accuracy: 0.9900
# Epoch 18/50
# 57/57 [==============================] - 0s 6ms/step - loss: 0.0335 - accuracy: 0.9886 - val_loss: 0.0307 - val_accuracy: 0.9900
# Epoch 19/50
# 57/57 [==============================] - 0s 6ms/step - loss: 0.0330 - accuracy: 0.9886 - val_loss: 0.0304 - val_accuracy: 0.9900
# Epoch 20/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0321 - accuracy: 0.9886 - val_loss: 0.0294 - val_accuracy: 0.9900
# Epoch 21/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.0315 - accuracy: 0.9886 - val_loss: 0.0294 - val_accuracy: 0.9900
# Epoch 22/50
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0311 - accuracy: 0.9886 - val_loss: 0.0286 - val_accuracy: 0.9900
# Epoch 23/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0305 - accuracy: 0.9886 - val_loss: 0.0282 - val_accuracy: 0.9900
# Epoch 24/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0301 - accuracy: 0.9886 - val_loss: 0.0277 - val_accuracy: 0.9900
# Epoch 25/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0296 - accuracy: 0.9886 - val_loss: 0.0272 - val_accuracy: 0.9900
# Epoch 26/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0288 - accuracy: 0.9886 - val_loss: 0.0266 - val_accuracy: 0.9900
# Epoch 27/50
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0282 - accuracy: 0.9886 - val_loss: 0.0262 - val_accuracy: 0.9900
# Epoch 28/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0279 - accuracy: 0.9886 - val_loss: 0.0258 - val_accuracy: 0.9900
# Epoch 29/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0275 - accuracy: 0.9895 - val_loss: 0.0255 - val_accuracy: 0.9909
# Epoch 30/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0272 - accuracy: 0.9895 - val_loss: 0.0249 - val_accuracy: 0.9909
# Epoch 31/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.0266 - accuracy: 0.9895 - val_loss: 0.0246 - val_accuracy: 0.9909
# Epoch 32/50
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0261 - accuracy: 0.9895 - val_loss: 0.0242 - val_accuracy: 0.9909
# Epoch 33/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0257 - accuracy: 0.9895 - val_loss: 0.0239 - val_accuracy: 0.9909
# Epoch 34/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0252 - accuracy: 0.9895 - val_loss: 0.0235 - val_accuracy: 0.9909
# Epoch 35/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0251 - accuracy: 0.9895 - val_loss: 0.0232 - val_accuracy: 0.9909
# Epoch 36/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0246 - accuracy: 0.9895 - val_loss: 0.0233 - val_accuracy: 0.9909
# Epoch 37/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0245 - accuracy: 0.9895 - val_loss: 0.0230 - val_accuracy: 0.9909
# Epoch 38/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0241 - accuracy: 0.9895 - val_loss: 0.0224 - val_accuracy: 0.9909
# Epoch 39/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0237 - accuracy: 0.9895 - val_loss: 0.0222 - val_accuracy: 0.9909
# Epoch 40/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0236 - accuracy: 0.9895 - val_loss: 0.0218 - val_accuracy: 0.9909
# Epoch 41/50
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0233 - accuracy: 0.9895 - val_loss: 0.0217 - val_accuracy: 0.9909
# Epoch 42/50
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0227 - accuracy: 0.9895 - val_loss: 0.0213 - val_accuracy: 0.9909
# Epoch 43/50
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 0.9895 - val_loss: 0.0212 - val_accuracy: 0.9909
# Epoch 44/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0222 - accuracy: 0.9912 - val_loss: 0.0209 - val_accuracy: 0.9909
# Epoch 45/50
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.9912 - val_loss: 0.0205 - val_accuracy: 0.9909
# Epoch 46/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.0217 - accuracy: 0.9912 - val_loss: 0.0205 - val_accuracy: 0.9909
# Epoch 47/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0213 - accuracy: 0.9912 - val_loss: 0.0201 - val_accuracy: 0.9909
# Epoch 48/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.0213 - accuracy: 0.9912 - val_loss: 0.0200 - val_accuracy: 0.9909
# Epoch 49/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0209 - accuracy: 0.9912 - val_loss: 0.0197 - val_accuracy: 0.9909
# Epoch 50/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0209 - accuracy: 0.9912 - val_loss: 0.0195 - val_accuracy: 0.9909

# %%
#print(k_adera.history.keys())
#print(k_adera.history['val_loss'])
#print(k_adera.history['val_accuracy'])
#print(k_adera.history['mape'])
results = grace_model.evaluate(Input_Adera_numpy2,Output_net_Adera3,batch_size=400)
# summarize history for accuracy
plt.plot(k_adera.history['accuracy'])
plt.plot(k_adera.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
axes = plt.gca()
#axes.set_ylim([-0.005,0.005])
plt.plot(k_adera.history['loss'])
plt.plot(k_adera.history['val_loss'])
#########################
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
#plt.title('model mape')
#plt.plot(k_adera.history['mean_squared_error'])
#plt.plot(k_adera.history['val_mape'])
#plt.plot(k_adera.history['mape'])
#plt.ylabel('mape')
#plt.xlabel('epoch')
#plt.show()
#plt.title('model mae')
#plt.plot(k_adera.history['val_mae'])
#plt.plot(k_adera.history['mae'])
#plt.show()
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0199 - accuracy: 0.9910

# %%
grace_model.save("adera+99+99+softmax+digetsive+system")
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.

# %%
adera_47_40_model = tf.keras.saving.load_model("adera+95+95+sigmoid+digetsive+system")

# %%
First_data_adera3c["Cancer_type"].unique()
data_adera= {
    "types":First_data_adera3c["Cancer_type"].unique(),
    "values": [0, 1]
}
import random
from keras.utils.np_utils import to_categorical


 # print(adera_test)
#Input_Adera_numpy2[adera_test].shape
#data_adera

threshold = 0.85  # Set the threshold for prediction

num_runs = 3
accuracies = []

for run in range(num_runs):
    adera_test = [random.randint(0, Adera_chromosome4.shape[0]-1) for _ in range(99)]
    correct_predictions = 0
    total_predictions = 0

    for adera_test1 in adera_test:
        test_mac = Input_Adera_numpy2[adera_test1].reshape(1, 1, 1, 8)
        adera_result = adera_47_40_model.predict(test_mac)
        print("adera_result=",adera_result)


        adera_result_thresholded = (adera_result >= threshold).astype(int)
        adera_result5 = np.argmax(adera_result_thresholded)
       # print("adera_result5=",adera_result5)

        if data_adera['types'][adera_result5] == First_data_adera3c['Cancer_type'].iloc[adera_test1]:
            #print("data_adera['types'][adera_result5] =", data_adera['types'][adera_result5])
           # print("data_adera['types'][adera_result5]=",data_adera['types'][adera_result5])
            correct_predictions += 1

        total_predictions += 1

    accuracy = correct_predictions / total_predictions
    accuracies.append(accuracy)

mean_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)

print("Mean accuracy:", mean_accuracy)
print("Standard deviation of accuracy:", std_accuracy)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.13621739 0.8636842 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.1370564 0.8628574]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.02246535 0.9769166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.05702516 0.94289577]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.03259125 0.9672822 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02257695 0.9767946 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.0572025  0.94269884]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.10051692 0.9005696 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.05700701 0.9429144 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.1251537 0.8755288]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.00980041 0.9900673 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.22064653 0.77975035]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.03265235 0.96721274]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.1369586 0.8629619]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.00328824 0.99746245]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.13477021 0.8652943 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.1374681 0.8624059]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.05892447 0.94086206]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.13621739 0.8636842 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.0225402  0.97683465]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.01748827 0.98232466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.05820712 0.9416002 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.02247401 0.9769079 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.10067372 0.90039164]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.05862993 0.9411727 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 32ms/step
# adera_result= [[[[0.00328824 0.99746245]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.21880785 0.78163433]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.01748827 0.98232466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 33ms/step
# adera_result= [[[[0.13729946 0.862598  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.05862993 0.9411727 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.21880785 0.78163433]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.02260732 0.9767611 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.02252721 0.9768493 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.05818473 0.9423635 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.13674921 0.8631854 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.10051692 0.9005696 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 34ms/step
# adera_result= [[[[0.02253187 0.9768442 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.13621739 0.8636842 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.2184322 0.7821089]]]]
# adera_result5= 0
# data_adera['types'][adera_result5] = Brain_Lower_Grade_Glioma
# data_adera['types'][adera_result5]= Brain_Lower_Grade_Glioma
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.02260732 0.9767611 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.14125639 0.85825986]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.00328824 0.99746245]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.01748827 0.98232466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.00329515 0.9974573 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.13477021 0.8652943 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.0126501 0.986965 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.12216564 0.87868154]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.22295333 0.7771023 ]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.0567836  0.94383574]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.02247401 0.9769079 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03280104 0.9670505 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.1370564 0.8628574]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.13667674 0.8632626 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02245848 0.97692466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.0126501 0.986965 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.01265541 0.986959  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.05700701 0.9429144 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.05700701 0.9429144 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.21880785 0.78163433]]]]
# adera_result5= 0
# data_adera['types'][adera_result5] = Brain_Lower_Grade_Glioma
# data_adera['types'][adera_result5]= Brain_Lower_Grade_Glioma
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.05818473 0.9423635 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.03259962 0.9672729 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.03323251 0.9665932 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.0058688 0.9954813]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.13699895 0.86291873]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.13621739 0.8636842 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.02243916 0.9769444 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02257695 0.9767946 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.0567836  0.94383574]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.02247401 0.9769079 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.03359918 0.96620125]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03437506 0.965352  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 32ms/step
# adera_result= [[[[0.03359918 0.96620125]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.1370564 0.8628574]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.13477021 0.8652943 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.21805242 0.78243965]]]]
# adera_result5= 0
# data_adera['types'][adera_result5] = Brain_Lower_Grade_Glioma
# data_adera['types'][adera_result5]= Brain_Lower_Grade_Glioma
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.01266084 0.9869526 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.1370564 0.8628574]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.05712646 0.9427812 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.13699895 0.86291873]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.03259962 0.9672729 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.02259145 0.9767763 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 32ms/step
# adera_result= [[[[0.03323251 0.9665932 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.1369586 0.8629619]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.01746572 0.9823495 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.22064653 0.77975035]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.2184322 0.7821089]]]]
# adera_result5= 0
# data_adera['types'][adera_result5] = Brain_Lower_Grade_Glioma
# data_adera['types'][adera_result5]= Brain_Lower_Grade_Glioma
# 1/1 [==============================] - 0s 85ms/step
# adera_result= [[[[0.03185876 0.96806383]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 117ms/step
# adera_result= [[[[0.01265541 0.986959  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 89ms/step
# adera_result= [[[[0.21880785 0.78163433]]]]
# adera_result5= 0
# data_adera['types'][adera_result5] = Brain_Lower_Grade_Glioma
# data_adera['types'][adera_result5]= Brain_Lower_Grade_Glioma
# 1/1 [==============================] - 0s 95ms/step
# adera_result= [[[[0.05702207 0.9429012 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 267ms/step
# adera_result= [[[[0.13729946 0.862598  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 233ms/step
# adera_result= [[[[0.02255577 0.9768155 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 212ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 105ms/step
# adera_result= [[[[0.03359918 0.96620125]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 96ms/step
# adera_result= [[[[0.1370564 0.8628574]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 107ms/step
# adera_result= [[[[0.05869773 0.9417778 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 43ms/step
# adera_result= [[[[0.01748827 0.98232466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.03265235 0.96721274]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 39ms/step
# adera_result= [[[[0.00330034 0.9974517 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 58ms/step
# adera_result= [[[[0.09946923 0.90167844]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 55ms/step
# adera_result= [[[[0.01263909 0.9869763 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 43ms/step
# adera_result= [[[[0.00329246 0.9974594 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 55ms/step
# adera_result= [[[[0.13619412 0.8637774 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 54ms/step
# adera_result= [[[[0.01273418 0.986872  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 97ms/step
# adera_result= [[[[0.03303893 0.9667885 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 83ms/step
# adera_result= [[[[0.0126501 0.986965 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 54ms/step
# adera_result= [[[[0.05702207 0.9429012 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.03303893 0.9667885 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 100ms/step
# adera_result= [[[[0.13619412 0.8637774 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 108ms/step
# adera_result= [[[[0.02259145 0.9767763 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.10088675 0.90015674]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 43ms/step
# adera_result= [[[[0.05811961 0.94242275]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 69ms/step
# adera_result= [[[[0.14125639 0.85825986]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 46ms/step
# adera_result= [[[[0.02260732 0.9767611 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 87ms/step
# adera_result= [[[[0.01263909 0.9869763 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 47ms/step
# adera_result= [[[[0.1369586 0.8629619]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 59ms/step
# adera_result= [[[[0.09912956 0.9020181 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 54ms/step
# adera_result= [[[[0.02246535 0.9769166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 62ms/step
# adera_result= [[[[0.02245848 0.97692466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 51ms/step
# adera_result= [[[[0.13699895 0.86291873]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 40ms/step
# adera_result= [[[[0.21880785 0.78163433]]]]
# adera_result5= 0
# data_adera['types'][adera_result5] = Brain_Lower_Grade_Glioma
# data_adera['types'][adera_result5]= Brain_Lower_Grade_Glioma
# 1/1 [==============================] - 0s 41ms/step
# adera_result= [[[[0.00328824 0.99746245]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.03259962 0.9672729 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 55ms/step
# adera_result= [[[[0.05820712 0.9416002 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 53ms/step
# adera_result= [[[[0.21652316 0.7841369 ]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.09823193 0.9029613 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.10088675 0.90015674]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.03290707 0.9669432 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.2184322 0.7821089]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03185876 0.96806383]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.01271732 0.98689055]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.0225352 0.9768407]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 44ms/step
# adera_result= [[[[0.05784982 0.94200456]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 79ms/step
# adera_result= [[[[0.01263909 0.9869763 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 67ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 42ms/step
# adera_result= [[[[0.22295333 0.7771023 ]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 54ms/step
# adera_result= [[[[0.03280104 0.9670505 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 60ms/step
# adera_result= [[[[0.09823193 0.9029613 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 80ms/step
# adera_result= [[[[0.22064653 0.77975035]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 48ms/step
# adera_result= [[[[0.13694538 0.8629759 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 55ms/step
# adera_result= [[[[0.01260301 0.9870166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 44ms/step
# adera_result= [[[[0.02245848 0.97692466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.22064653 0.77975035]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.00327364 0.9974745 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 65ms/step
# adera_result= [[[[0.10067372 0.90039164]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 52ms/step
# adera_result= [[[[0.0225352 0.9768407]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 153ms/step
# adera_result= [[[[0.13699895 0.86291873]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.12805742 0.8724431 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.05818473 0.9423635 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.03437506 0.965352  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.14125639 0.85825986]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.00980041 0.9900673 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.00327364 0.9974745 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.01260301 0.9870166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 33ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.01263909 0.9869763 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.02246535 0.9769166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 49ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 41ms/step
# adera_result= [[[[0.03259125 0.9672822 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 48ms/step
# adera_result= [[[[0.02247401 0.9769079 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.09823193 0.9029613 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.01272298 0.98688483]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 46ms/step
# adera_result= [[[[0.13694538 0.8629759 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 51ms/step
# adera_result= [[[[0.14125639 0.85825986]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 41ms/step
# adera_result= [[[[0.05928499 0.9411107 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.1368877  0.86303747]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 39ms/step
# adera_result= [[[[0.01263176 0.9869842 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 40ms/step
# adera_result= [[[[0.13694538 0.8629759 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 39ms/step
# adera_result= [[[[0.01273418 0.986872  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 39ms/step
# adera_result= [[[[0.21880785 0.78163433]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 42ms/step
# adera_result= [[[[0.02246535 0.9769166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 41ms/step
# adera_result= [[[[0.05700701 0.9429144 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.02247401 0.9769079 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 41ms/step
# adera_result= [[[[0.0058688 0.9954813]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 36ms/step
# adera_result= [[[[0.05862993 0.9411727 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.01271732 0.98689055]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 46ms/step
# adera_result= [[[[0.2184322 0.7821089]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 45ms/step
# adera_result= [[[[0.03259962 0.9672729 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 47ms/step
# adera_result= [[[[0.13699895 0.86291873]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 43ms/step
# adera_result= [[[[0.02245848 0.97692466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.22064653 0.77975035]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 39ms/step
# adera_result= [[[[0.21805242 0.78243965]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 48ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 42ms/step
# adera_result= [[[[0.01272298 0.98688483]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 43ms/step
# adera_result= [[[[0.03290707 0.9669432 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 44ms/step
# adera_result= [[[[0.02253187 0.9768442 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 38ms/step
# adera_result= [[[[0.13477021 0.8652943 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 34ms/step
# adera_result= [[[[0.03303893 0.9667885 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 47ms/step
# adera_result= [[[[0.05869773 0.9417778 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.0225402  0.97683465]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 36ms/step
# adera_result= [[[[0.21805242 0.78243965]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02252721 0.9768493 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.0572025  0.94269884]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.02257695 0.9767946 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.01265143 0.9869634 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.09823193 0.9029613 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.12805742 0.8724431 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.00329246 0.9974594 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.13699895 0.86291873]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.05702207 0.9429012 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.02260732 0.9767611 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.01265541 0.986959  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 33ms/step
# adera_result= [[[[0.05820712 0.9416002 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.03265235 0.96721274]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.05892447 0.94086206]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.13699895 0.86291873]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 32ms/step
# adera_result= [[[[0.01269122 0.9869195 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.01266084 0.9869526 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.02246535 0.9769166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.13699895 0.86291873]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.21652316 0.7841369 ]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 33ms/step
# adera_result= [[[[0.22064653 0.77975035]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.05928499 0.9411107 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.03265235 0.96721274]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# ...
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.10051692 0.9005696 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 46ms/step
# adera_result= [[[[0.02255577 0.9768155 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.0572025  0.94269884]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03261223 0.9672586 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.0058688 0.9954813]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.01746572 0.9823495 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.09912956 0.9020181 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.22295333 0.7771023 ]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03323251 0.9665932 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.05892447 0.94086206]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.22295333 0.7771023 ]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.13694538 0.8629759 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.13650487 0.86344606]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02259145 0.9767763 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.02257695 0.9767946 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.13667674 0.8632626 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03259125 0.9672822 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.1389287 0.8607491]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.05702207 0.9429012 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.05715462 0.9427588 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 33ms/step
# adera_result= [[[[0.01263176 0.9869842 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03303893 0.9667885 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.05892447 0.94086206]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.1368877  0.86303747]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.00330034 0.9974517 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.13685545 0.86307186]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.21652316 0.7841369 ]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.02244864 0.976935  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.01750956 0.98230106]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.13685545 0.86307186]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02255577 0.9768155 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.05712646 0.9427812 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.02246535 0.9769166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.22052212 0.77988297]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.00330034 0.9974517 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.01271732 0.98689055]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.05715462 0.9427588 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.05928499 0.9411107 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.01260301 0.9870166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.1369586 0.8629619]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.03185876 0.96806383]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02260732 0.9767611 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.2153977 0.7852418]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03261223 0.9672586 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.10051692 0.9005696 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.13712467 0.86278445]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.1389287 0.8607491]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.05702516 0.94289577]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.00329515 0.9974573 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.05869773 0.9417778 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.05702207 0.9429012 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.13729946 0.862598  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.13694538 0.8629759 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.01265541 0.986959  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.1365516 0.8633962]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.0126501 0.986965 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.1251537 0.8755288]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.05892447 0.94086206]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.01748827 0.98232466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.00327364 0.9974745 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.01273418 0.986872  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02252721 0.9768493 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.01271732 0.98689055]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.01266084 0.9869526 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.02245848 0.97692466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.13650487 0.86344606]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.09912956 0.9020181 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02246535 0.9769166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# Mean accuracy: 0.8720538720538721
# Standard deviation of accuracy: 0.004761661826172016

# %%
correct_predictions
# Out:
# 3
